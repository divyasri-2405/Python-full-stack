# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
a=[10,20,30,40,50]
pd.Series(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
b=[23.4,78.6,65.4,19.2,78.9]
pd.Series(b)
# Out:
# 0    23.4
# 1    78.6
# 2    65.4
# 3    19.2
# 4    78.9
# dtype: float64

# %%
c=["Python","java","c++","c","django"]
pd.Series(c)
# Out:
# 0    Python
# 1      java
# 2       c++
# 3         c
# 4    django
# dtype: str

# %%
d=[8+9j,5j,7j+8,3j+10,4j+6]
pd.Series(d)
# Out:
# 0     8.0+ 9.0j
# 1     0.0+ 5.0j
# 2     8.0+ 7.0j
# 3    10.0+ 3.0j
# 4     6.0+ 4.0j
# dtype: complex128

# %%
e=[True,False]
pd.Series(e)
# Out:
# 0     True
# 1    False
# dtype: bool

# %%
d={"names":["kavya","divya","vaishnavi"],"marks":[70,80,90]}
pd.DataFrame(d)
# Out:
#        names  marks
# 0      kavya     70
# 1      divya     80
# 2  vaishnavi     90

# %%
d={"Names":["kumar","girija","bharath"],"marks":[100,98,89],"grades":['A','B','C']}
pd.DataFrame(d)
# Out:
#      Names  marks grades
# 0    kumar    100      A
# 1   girija     98      B
# 2  bharath     89      C

# %%
d={"Names":["divya","kavya","vaishnavi","kumar","girija"],"Subjects":["social","Telugu","hindi","english","science"],"marks":[90,80,70,98,100]}
pd.DataFrame(d)
# Out:
#        Names Subjects  marks
# 0      divya   social     90
# 1      kavya   Telugu     80
# 2  vaishnavi    hindi     70
# 3      kumar  english     98
# 4     girija  science    100

# %%
d=pd.read_csv("Book1.csv")
d
# Out:
#         name  marks    subject
# 0      divya     90     social
# 1      sajad     93      hindi
# 2    adraysh     87    english
# 3    adrayth     80     telugu
# 4      varna     78   sanskrit
# 5      kumar     75      maths
# 6     girija     65    physics
# 7  vaishnavi     60  chemistry
# 8      kavya     92    biology

# %%
d.columns
# Out:
# Index(['name', 'marks', 'subject'], dtype='str')

# %%
d.shape
# Out:
# (9, 3)

# %%
d.info
# Out:
# <bound method DataFrame.info of         name  marks    subject
# 0      divya     90     social
# 1      sajad     93      hindi
# 2    adraysh     87    english
# 3    adrayth     80     telugu
# 4      varna     78   sanskrit
# 5      kumar     75      maths
# 6     girija     65    physics
# 7  vaishnavi     60  chemistry
# 8      kavya     92    biology>

# %%
data=pd.read_csv("cumulative.csv")
data
# Out:
#       rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2         3  10811496  K00753.01           NaN  FALSE POSITIVE
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...     ...       ...        ...           ...             ...
# 9559   9560  10031643  K07984.01           NaN  FALSE POSITIVE
# 9560   9561  10090151  K07985.01           NaN  FALSE POSITIVE
# 9561   9562  10128825  K07986.01           NaN       CANDIDATE
# 9562   9563  10147276  K07987.01           NaN  FALSE POSITIVE
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE      1.000              0              0              0
# ...

# %%
data.columns
# Out:
# Index(['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
#        'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
#        'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
#        'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
#        'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='str')

# %%
data.shape
# Out:
# (9564, 50)

# %%
data.info
# Out:
# <bound method DataFrame.info of       rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2         3  10811496  K00753.01           NaN  FALSE POSITIVE
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...     ...       ...        ...           ...             ...
# 9559   9560  10031643  K07984.01           NaN  FALSE POSITIVE
# 9560   9561  10090151  K07985.01           NaN  FALSE POSITIVE
# 9561   9562  10128825  K07986.01           NaN       CANDIDATE
# 9562   9563  10147276  K07987.01           NaN  FALSE POSITIVE
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE      1.000              0              0              0
# ...
