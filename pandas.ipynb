# %% [markdown]
# 31-07-2026

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.0 MB 2.7 MB/s eta 0:00:04
#    -- ------------------------------------- 0.5/10.0 MB 2.7 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/10.0 MB 1.0 MB/s eta 0:00:10
#    --- ------------------------------------ 0.8/10.0 MB 1.0 MB/s eta 0:00:10
#    --- ------------------------------------ 0.8/10.0 MB 1.0 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.3/10.0 MB 853.5 kB/s eta 0:00:11
#    ------ --------------------------------- 1.6/10.0 MB 968.3 kB/s eta 0:00:09
#    ------- -------------------------------- 1.8/10.0 MB 929.8 kB/s eta 0:00:09
#    -------- ------------------------------- 2.1/10.0 MB 975.1 kB/s eta 0:00:09
# ...

# %%
import pandas as pd

# %%
a=[10,20,30,40,50]
pd.Series(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
b=[23.4,34.8,89.1,11.4,90.12]
pd.Series(b)
# Out:
# 0    23.40
# 1    34.80
# 2    89.10
# 3    11.40
# 4    90.12
# dtype: float64

# %%
c=["Python","java","c++","c"]
pd.Series(c)
# Out:
# 0    Python
# 1      java
# 2       c++
# 3         c
# dtype: str

# %%
d=[6+8j,9j,4j+2,19+8j]
pd.Series(d)
# Out:
# 0     6.0+ 8.0j
# 1     0.0+ 9.0j
# 2     2.0+ 4.0j
# 3    19.0+ 8.0j
# dtype: complex128

# %%
f=[True,False]
pd.Series(f)
# Out:
# 0     True
# 1    False
# dtype: bool

# %%
d={"names":["Kavya","suma","anjali"],"marks":[60,70,80]}
pd.DataFrame(d)
# Out:
#     names  marks
# 0   Kavya     60
# 1    suma     70
# 2  anjali     80

# %%
d={"names":["kavya","suma","anjali"],"marks":[60,70,80],"grades":['A','B','C']}
pd.DataFrame(d)
# Out:
#     names  marks grades
# 0   kavya     60      A
# 1    suma     70      B
# 2  anjali     80      C

# %%
d={"names":["divya","kavya","vaishu","girija","kumar"],"subjects":["social","maths","physics","chemistry","biology"],"marks":[90,80,97,88,93]}
pd.DataFrame(d)
# Out:
#     names   subjects  marks
# 0   divya     social     90
# 1   kavya      maths     80
# 2  vaishu    physics     97
# 3  girija  chemistry     88
# 4   kumar    biology     93

# %%
#reading and printing the data using external csv file
data=pd.read_csv("Book1.csv")
data
# Out:
#         name  marks    subject
# 0      divya     90     social
# 1      sajad     93      hindi
# 2    adraysh     87    english
# 3    adrayth     80     telugu
# 4      varna     78   sanskrit
# 5      kumar     75      maths
# 6     girija     65    physics
# 7  vaishnavi     60  chemistry
# 8      kavya     92    biology

# %%
data.columns
# Out:
# Index(['name', 'marks', 'subject'], dtype='str')

# %%
data.shape
# Out:
# (9, 3)

# %%
data.info
# Out:
# <bound method DataFrame.info of         name  marks    subject
# 0      divya     90     social
# 1      sajad     93      hindi
# 2    adraysh     87    english
# 3    adrayth     80     telugu
# 4      varna     78   sanskrit
# 5      kumar     75      maths
# 6     girija     65    physics
# 7  vaishnavi     60  chemistry
# 8      kavya     92    biology>

# %%
d=pd.read_csv("cumulative.csv")
d
# Out:
#       rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2         3  10811496  K00753.01           NaN  FALSE POSITIVE
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...     ...       ...        ...           ...             ...
# 9559   9560  10031643  K07984.01           NaN  FALSE POSITIVE
# 9560   9561  10090151  K07985.01           NaN  FALSE POSITIVE
# 9561   9562  10128825  K07986.01           NaN       CANDIDATE
# 9562   9563  10147276  K07987.01           NaN  FALSE POSITIVE
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE      1.000              0              0              0
# ...

# %%
d.columns
# Out:
# Index(['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
#        'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
#        'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
#        'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
#        'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='str')

# %%
d.shape
# Out:
# (9564, 50)

# %%
d.info
# Out:
# <bound method DataFrame.info of       rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2         3  10811496  K00753.01           NaN  FALSE POSITIVE
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...     ...       ...        ...           ...             ...
# 9559   9560  10031643  K07984.01           NaN  FALSE POSITIVE
# 9560   9561  10090151  K07985.01           NaN  FALSE POSITIVE
# 9561   9562  10128825  K07986.01           NaN       CANDIDATE
# 9562   9563  10147276  K07987.01           NaN  FALSE POSITIVE
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE      1.000              0              0              0
# ...
