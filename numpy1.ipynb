# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
a=np.array(50)
print(a)
print(a.ndim)
print(type(a))
# Out:
# 50
# 0
# <class 'numpy.ndarray'>

# %%
a=np.array([1,2,3,4])
print(a)
print(a.ndim)
print(type(a))
# Out:
# [1 2 3 4]
# 1
# <class 'numpy.ndarray'>

# %%
a=np.array([[1,2,3,4],[5,6,7,8]])
print(a)
print(a.ndim)
print(type(a))
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]
# 2
# <class 'numpy.ndarray'>

# %%
a=np.array([[[1,2,3,4],[5,6,7,8]],[[8,9,10,10],[11,12,13,14]]])
print(a)
print(a.ndim)
print(type(a))
# Out:
# [[[ 1  2  3  4]
#   [ 5  6  7  8]]
#
#  [[ 8  9 10 10]
#   [11 12 13 14]]]
# 3
# <class 'numpy.ndarray'>

# %%
e=np.array([1,2.3,"python",7+8j,True,False])
print(e)
print(e.ndim)
print(type(e))
# Out:
# ['1' '2.3' 'python' '(7+8j)' 'True' 'False']
# 1
# <class 'numpy.ndarray'>

# %%
a=[1,2,3,4,8]
b=[4,5,6,7,9]
print(a+b)
# Out:
# [1, 2, 3, 4, 8, 4, 5, 6, 7, 9]

# %%
a=np.array([1,2,3,4,8])
b=np.array([4,5,6,7,9])
print(a+b)
# Out:
# [ 5  7  9 11 17]

# %%
c=np.sum(a)
print(c)
# Out:
# 18

# %%
d=np.sum(b)
print(d)
# Out:
# 31

# %%
e=np.mean(a)
print(e)
# Out:
# 3.6

# %%
f=np.mean(b)
print(f)
# Out:
# 6.2
