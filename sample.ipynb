# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a=int(input("a value:"))
b=int(input("b value:"))
print(a+b)
# Out:
# a value: 6
# b value: 8
# 14

# %%
a=int(input())
b=int(input())
print(a+b)
# Out:
#  56
#  67
# 123
