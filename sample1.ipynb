# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a=int(input("enter a value"))
b=int(input("enter b value"))
print(a+b)
# Out:
# enter a value 45
# enter b value 67
# 112

# %%
a=int(input())
b=int(input())
print(a+b)
# Out:
#  78
#  65
# 143
